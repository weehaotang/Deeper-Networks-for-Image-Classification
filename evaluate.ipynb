# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
vgg_mnist = [0.9894, 0.9911, 0.9915, 0.992, 0.9935, 0.9922, 0.9922, 0.9923,
             0.9938, 0.9922, 0.9945, 0.994, 0.9954, 0.9949, 0.9927, 0.9944,
             0.9952, 0.994, 0.9932, 0.9946, 0.9947, 0.9947, 0.9949, 0.995,
             0.995, 0.9952, 0.995, 0.9952, 0.9952, 0.9952, 0.9951, 0.9951,
             0.9951, 0.9951, 0.9951, 0.9951, 0.9951, 0.9951, 0.9951, 0.9951,
             0.9951, 0.9951, 0.9951, 0.9951, 0.9951, 0.9951, 0.9951, 0.9951,
             0.9951, 0.9951]
res18_mnist = [0., 0.9886, 0.9861, 0.9916, 0.9933, 0.9934, 0.9934, 0.9933, 0.9924, 0.9929, 0.9944, 0.9931, 0.9937, 0.9935, 0.9954, 0.9935, 0.9933, 0.9938, 0.9936, 0.993, 0.9948, 0.9952, 0.9951, 0.9951, 0.995,
               0.995, 0.995, 0.995, 0.995, 0.995, 0.995, 0.995, 0.9951, 0.9951, 0.9952, 0.9952, 0.9952, 0.9952, 0.9952, 0.9952, 0.9952, 0.9952, 0.9952, 0.9952, 0.9952, 0.9952, 0.9952, 0.9952, 0.9952, 0.9952, 0.9952]
google_mnist = [0.9913, 0.9901, 0.9936, 0.989, 0.9924, 0.9917, 0.9921, 0.995,
                0.9964, 0.9951, 0.9932, 0.9944, 0.9942, 0.995, 0.9934, 0.9945,
                0.9944, 0.996, 0.9954, 0.9945, 0.9955, 0.994, 0.9928, 0.996,
                0.9949, 0.9959, 0.995, 0.9959, 0.9951, 0.9954, 0.9963, 0.9961,
                0.9956, 0.996, 0.9957, 0.9959, 0.9959, 0.9958, 0.9959, 0.996,
                0.9959, 0.9959, 0.9959, 0.9959, 0.9959, 0.9959, 0.996, 0.9959,
                0.9958, 0.9958]

x = np.linspace(1, 50, 50)
plt.title('MNIST')
plt.plot(x, vgg_mnist[0:50], color='blue', label='vgg_mnist')
plt.plot(x, res18_mnist[1:51], color='red', label='res18_mnist')
plt.plot(x, google_mnist[0:50], color='green', label='google_mnist')
plt.legend(['VGG', 'RES18', 'Google'])

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
vgg_cifar = [0.1759, 0.2218, 0.2715, 0.3001, 0.2661, 0.3605, 0.3813, 0.4329,
             0.5211, 0.5087, 0.6122, 0.61, 0.6153, 0.6677, 0.7146, 0.7212,
             0.7615, 0.7404, 0.7596, 0.7581, 0.7711, 0.7771, 0.7847, 0.7602,
             0.7999, 0.7972, 0.8084, 0.8267, 0.8037, 0.8153, 0.8153, 0.8245,
             0.8278, 0.8275, 0.8456, 0.8418, 0.8434, 0.8213, 0.8292, 0.8518,
             0.8327, 0.8521, 0.8485, 0.8511, 0.8498, 0.8503, 0.8428, 0.8632,
             0.864, 0.8668]
res18_cifar = [0., 0.5295, 0.6366, 0.7142, 0.7466, 0.7836, 0.8103, 0.8168, 0.8326, 0.8255, 0.8426, 0.8529, 0.8574, 0.8624, 0.8655, 0.8702, 0.8809, 0.8773, 0.8748, 0.8866, 0.8848, 0.8797, 0.8722, 0.8878, 0.8879,
               0.8831, 0.8828, 0.8924, 0.8838, 0.8871, 0.8905, 0.8914, 0.894, 0.8882, 0.8939, 0.8941, 0.8904, 0.8939, 0.8899, 0.8976, 0.8844, 0.898, 0.893, 0.8853, 0.8966, 0.8973, 0.8958, 0.8924, 0.9026, 0.8868, 0.8985]

google_cifar = [0.5763, 0.6358, 0.6911, 0.7465, 0.7588, 0.7911, 0.7973, 0.8276,
                0.8378, 0.812, 0.7661, 0.8123, 0.8551, 0.8495, 0.8634, 0.8531,
                0.8596, 0.8617, 0.865, 0.8726, 0.8752, 0.8866, 0.8752, 0.8673,
                0.88, 0.8859, 0.8885, 0.8728, 0.8726, 0.883, 0.8858, 0.8843,
                0.8861, 0.875, 0.8836, 0.8864, 0.8944, 0.8947, 0.8891, 0.8842,
                0.8946, 0.887, 0.8918, 0.8977, 0.8877, 0.8839, 0.902, 0.8865,
                0.8992, 0.8853]

x = np.linspace(1, 50, 50)
plt.title('CIFAR10')
plt.plot(x, vgg_cifar[0:50], color='red', label='vgg_cifar')
plt.plot(x, res18_cifar[1:51], color='blue', label='res18_cifar')
plt.plot(x, google_cifar[0:50], color='green', label='google_cifar')
plt.legend(['VGG', 'RES18', 'Google', 'RES34'])

plt.xlabel('Eopches')
plt.ylabel('Accuracy')
plt.show()

# %%
res18_cifar = [0., 0.5295, 0.6366, 0.7142, 0.7466, 0.7836, 0.8103, 0.8168, 0.8326, 0.8255, 0.8426, 0.8529, 0.8574, 0.8624, 0.8655, 0.8702, 0.8809, 0.8773, 0.8748, 0.8866, 0.8848, 0.8797, 0.8722, 0.8878, 0.8879,
               0.8831, 0.8828, 0.8924, 0.8838, 0.8871, 0.8905, 0.8914, 0.894, 0.8882, 0.8939, 0.8941, 0.8904, 0.8939, 0.8899, 0.8976, 0.8844, 0.898, 0.893, 0.8853, 0.8966, 0.8973, 0.8958, 0.8924, 0.9026, 0.8868, 0.8985]


res_adam = [0., 0.4701, 0.5826, 0.6508, 0.6811, 0.7219, 0.7635, 0.7827,
            0.783, 0.7929, 0.8114, 0.8031, 0.8102, 0.817, 0.8325, 0.8431,
            0.8491, 0.8299, 0.8316, 0.8449, 0.8459, 0.8503, 0.8532, 0.8471,
            0.8525, 0.8584, 0.8577, 0.8298, 0.853, 0.853, 0.8571, 0.8627,
            0.8672, 0.8603, 0.8536, 0.8661, 0.8514, 0.8595, 0.8721, 0.8614,
            0.8545, 0.8662, 0.8652, 0.863, 0.8739, 0.8739, 0.8576, 0.8729,
            0.8644, 0.8707, 0.8644]


x = np.linspace(1, 50, 50)
plt.title('SGD_ADAM(CIFAR10)')

plt.plot(x, res18_cifar[1:51], color='blue', label='res18_cifar')
plt.plot(x, res_adam[1:51], color='red', label='res_adam')

plt.legend(['RES_SGD', 'RES_ADAM', ])

plt.xlabel('Eopches')
plt.ylabel('Accuracy')
plt.show()

# %%
google_cifar = [0.5763, 0.6358, 0.6911, 0.7465, 0.7588, 0.7911, 0.7973, 0.8276,
                0.8378, 0.812, 0.7661, 0.8123, 0.8551, 0.8495, 0.8634, 0.8531,
                0.8596, 0.8617, 0.865, 0.8726, 0.8752, 0.8866, 0.8752, 0.8673,
                0.88, 0.8859, 0.8885, 0.8728, 0.8726, 0.883, 0.8858, 0.8843,
                0.8861, 0.875, 0.8836, 0.8864, 0.8944, 0.8947, 0.8891, 0.8842,
                0.8946, 0.887, 0.8918, 0.8977, 0.8877, 0.8839, 0.902, 0.8865,
                0.8992, 0.8853]

google_adam = [0.4415, 0.5259, 0.5866, 0.6003, 0.642, 0.6731, 0.7021, 0.7188,
               0.6625, 0.7561, 0.7399, 0.7731, 0.7273, 0.7348, 0.7781, 0.7959,
               0.7393, 0.7883, 0.7877, 0.7833, 0.8066, 0.7738, 0.7972, 0.7902,
               0.8153, 0.8125, 0.8164, 0.8295, 0.8095, 0.8269, 0.8206, 0.8243,
               0.8266, 0.8253, 0.8211, 0.8301, 0.8353, 0.8305, 0.8378, 0.8432,
               0.8392, 0.8171, 0.8346, 0.8376, 0.8253, 0.8413, 0.8072, 0.8398,
               0.8481, 0.8447]

x = np.linspace(1, 50, 50)
plt.title('SGD_ADAM(CIFAR10)')

plt.plot(x, google_cifar[0:50], color='green', label='google_cifar')
plt.plot(x, google_adam[0:50], color='purple', label='google_adam')

plt.legend(['Google_SGD', 'Google_ADAM'])

plt.xlabel('Eopches')
plt.ylabel('Accuracy')
plt.show()
